# %%
import logging
from hamamatsu.dcam import dcam, Stream, copy_frame

logging.basicConfig(level=logging.INFO)

with dcam:
    camera = dcam[0]
    with camera:
        print(camera.info)
        print(camera['image_width'].value, camera['image_height'].value)

        # Simple acquisition example
        nb_frames = 10
        camera["exposure_time"] = 0.1
        with Stream(camera, nb_frames) as stream:
                logging.info("start acquisition")
                camera.start()
                for i, frame_buffer in enumerate(stream):
                    frame = copy_frame(frame_buffer)
                    logging.info(f"acquired frame #%d/%d: %s", i+1, nb_frames, frame)
                logging.info("finished acquisition")
# Out:
# WARNING:root:Could not build capability 0x420830: ValueError('4327472 is not a valid EProp')
# WARNING:root:Could not build capability 0x420840: ValueError('4327488 is not a valid EProp')
# {<EIDString.BUS: 67109121>: 'AS-FBD-1XCLD-2PE4L', <EIDString.CAMERAID: 67109122>: 'S/N: 305140', <EIDString.VENDOR: 67109123>: 'Hamamatsu', <EIDString.MODEL: 67109124>: 'C13440-20C', <EIDString.CAMERAVERSION: 67109125>: '4.31.B', <EIDString.DRIVERVERSION: 67109126>: '8.13.30.6469', <EIDString.MODULEVERSION: 67109127>: '22.7.4322.6469', <EIDString.DCAMAPIVERSION: 67109128>: '4.00', <EIDString.CAMERA_SERIESNAME: 67109164>: 'ORCA-Flash4.0 V3'}
# 2048 2048
# ---------------------------------------------------------------------------
# DCAMError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18468\1290768866.py in <module>
#      13         nb_frames = 10
#      14         camera["exposure_time"] = 0.1
# ---> 15         with Stream(camera, nb_frames) as stream:
#      16                 logging.info("start acquisition")
#      17                 camera.start()
#
# ~\anaconda3\envs\rplab\lib\site-packages\hamamatsu\dcam.py in __init__(self, device, nb_frames)
#    1386         self.device = device
#    1387         self.nb_frames = nb_frames
# -> 1388         self.frame_stream = FrameStream(device, nb_frames)
#    1389         self.event_stream = EventStream(device)
#    1390         self.context_stack = contextlib.ExitStack()
#
# ~\anaconda3\envs\rplab\lib\site-packages\hamamatsu\dcam.py in __init__(self, device, nb_frames)
#    1323         self.device = device
#    1324         self.nb_frames = nb_frames
# -> 1325         self.device._buf_alloc(nb_frames)
#    1326         self.stream = device.frame_stream(nb_frames)
#    1327
#
# ~\anaconda3\envs\rplab\lib\site-packages\hamamatsu\dcam.py in _buf_alloc(self, nb_frames)
#    1659
#    1660     def _buf_alloc(self, nb_frames):
# -> 1661         self._lib.dcambuf_alloc(self._handle, nb_frames)
#    1662
#    1663     def _buf_release(self):
#
# ~\anaconda3\envs\rplab\lib\site-packages\hamamatsu\dcam.py in func(*args, **kwargs)
#    1830                 r = member(*args, **kwargs)
#    1831                 if r != EError.SUCCESS and ctypes.c_int32(r).value < 0:
# -> 1832                     raise DCAMError(EError(r), name)
#    1833
#    1834             setattr(self, name, func)
#
# DCAMError: DCAMError: 'dcambuf_alloc' raised NOTSTABLE (2147483908)
