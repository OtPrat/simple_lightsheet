# %% [markdown]
# Will need to install package from:
# https://github.com/uetke/UUTrack/tree/master

# %%
import matplotlib.pyplot as plt

# %%
from PyQt5.QtWidgets import QApplication

from UUTrack.Model.Cameras.Hamamatsu import camera
from views import StartWindow

# %%
camera = camera(0)
camera.initializeCamera()

# %%
camera.setAcquisitionMode(1)
camera.getAcquisitionMode()

# %%
camera.getSize()

# %%
camera.setExposure(10)
camera.getExposure()

# %%
camera.triggerCamera()

# %%
camera.stopAcq()

# %%
a = camera.readCamera()

# %%
a[0].shape

# %%
plt.figure()
plt.imshow(a[0])

# %%
plt.figure()
plt.imshow(a[2])

# %%
camera.getAcquisitionMode()

# %%
camera.setAcquisitionMode(1)

# %%
camera.getAcquisitionMode()

# %%
camera.triggerCamera()

# %%
a = camera.readCamera()

# %%
import matplotlib.pyplot as plt

# %%
plt.figure()
plt.imshow(a[2])

# %%
app = QApplication([])
start_window = StartWindow(camera)
start_window.show()
app.exit(app.exec_())
